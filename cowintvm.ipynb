# %%
import requests
import time


dist = 296
date = '14-08-2021'

URL = 'https://cdn-api.co-vin.in/api/v2/appointment/sessions/public/findByDistrict?district_id={}&date={}'.format(dist, date)

header = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.76 Safari/537.36'}

def findAvailability():
  counter = 0
  result = requests.get(URL, headers=header)
  response_json = result.json()
  data = response_json["sessions"]
  for center in data:
    if (center["available_capacity_dose1"]>0 and center['fee_type']!="Paid"):
      counter += 1
      print("------------------------------------------------------------------------")
      print(center["name"])
      print("PIN CODE: {}".format(center["pincode"]))
      print(center["vaccine"])
      print("Fee Type: {}".format(center["fee_type"]))
      print("Available dose1 : {}".format(center["available_capacity_dose1"]))
      print("------------------------------------------------------------------------")
    if (counter==0):
      print("No Available Slots in {}".format(center["district_name"]))

while True:
  findAvailability()
  time.sleep(5)
# Out:
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# No Available Slots in Thiruvananthapuram
# ...
