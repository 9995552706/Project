# %%
import telebot
import time
TOKEN = '949585121:AAFygdgvjPYqNX2eM9FVoLu1XRHQVkoO9s4'
bot = telebot.TeleBot(TOKEN)
@bot.message_handler(commands=['start'])
def send_welcome(message):
  fn=message.chat.first_name
  ln=message.chat.last_name
  bot.reply_to(message,'WELCOME TO AIC CLASSROOM '+ fn +' '+ln)
@bot.message_handler(commands=['introduction'])
def send_answer(message):
  doc=open('introduction.pdf','rb')
  bot.send_document(message.chat.id,doc)
  doc.close()
@bot.message_handler(commands=['differential'])
def send_answer(message):
  doc=open('differential_amplifiers.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=ltVspUteuuI')
  doc.close()
@bot.message_handler(commands=['opamp'])
def send_answer(message):
  doc=open('op-amp.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=kiiA6WTCQn0')
  doc.close()
@bot.message_handler(commands=['opampchara'])
def send_answer(message):
  doc=open('opamp_chara.pdf','rb')
  bot.send_document(message.chat.id,doc)
  doc.close()
@bot.message_handler(commands=['cmrr'])
def send_answer(message):
  doc=open('cmrr.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=hpCu3HbAiWg&t=249s')
  doc.close()

@bot.message_handler(commands=['slewrate'])
def send_answer(message):
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=2DFIr6t1hbc&t=624s')

@bot.message_handler(commands=['gbp'])
def send_answer(message):
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=wfkzz1rg-xk')

@bot.message_handler(commands=['negativefeedback'])
def send_answer(message):
  doc=open('negative_feedback.pdf','rb')
  bot.send_document(message.chat.id,doc)
  doc.close()

@bot.message_handler(commands=['inverting'])
def send_answer(message):
  doc=open('inverting_amplifier.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=AuZ00cQ0UrE&list=PLwjK_iyK4LLDBB1E9MFbxGCEnmMMOAXOH&index=2')
  doc.close()

@bot.message_handler(commands=['noninverting'])
def send_answer(message):
  doc=open('noninverting_amplifier.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=uyOfonR_rEw&list=PLwjK_iyK4LLDBB1E9MFbxGCEnmMMOAXOH&index=3')
  doc.close()

@bot.message_handler(commands=['summing'])
def send_answer(message):
  doc=open('summing_amplifier.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=jsKSfaFQ4d4&list=PLwjK_iyK4LLDBB1E9MFbxGCEnmMMOAXOH&index=4')
  doc.close()

@bot.message_handler(commands=['instrumentation'])
def send_answer(message):
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=pSctPegtZfc&list=PLwjK_iyK4LLDBB1E9MFbxGCEnmMMOAXOH&index=18')

@bot.message_handler(commands=['voltagetocurrent'])
def send_answer(message):
  doc=open('voltage_to_current_converter.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=DeDk0Rl3Oa0&list=PLwjK_iyK4LLDBB1E9MFbxGCEnmMMOAXOH&index=19')
  doc.close()

@bot.message_handler(commands=['currenttovoltage'])
def send_answer(message):
  doc=open('current_to_voltage_converter.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=OMnZehJNGCY&list=PLwjK_iyK4LLDBB1E9MFbxGCEnmMMOAXOH&index=20')
  doc.close()

@bot.message_handler(commands=['integrator'])
def send_answer(message):
  doc=open('integrator.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=OPvs7A554Rw&list=PLwjK_iyK4LLDBB1E9MFbxGCEnmMMOAXOH&index=6')
  doc.close()

@bot.message_handler(commands=['differentiator'])
def send_answer(message):
  doc=open('differentiator.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=aU24RWIgJVs&list=PLwjK_iyK4LLDBB1E9MFbxGCEnmMMOAXOH&index=7')
  doc.close()

@bot.message_handler(commands=['precisionrectifier'])
def send_answer(message):
  doc=open('precision_rectifier.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=5HweBajP-5g&list=PLwjK_iyK4LLDBB1E9MFbxGCEnmMMOAXOH&index=22')
  doc.close()

@bot.message_handler(commands=['logantilog'])
def send_answer(message):
  doc=open('log_and_antilog_amplifier.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=Nrfb-s0wl6g&list=PLwjK_iyK4LLDBB1E9MFbxGCEnmMMOAXOH&index=21')
  doc.close()

@bot.message_handler(commands=['weinbridgeoscillator'])
def send_answer(message):
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=gbUXbaxvX94&list=PLwjK_iyK4LLDBB1E9MFbxGCEnmMMOAXOH&index=25')

@bot.message_handler(commands=['multivibrator'])
def send_answer(message):
  doc=open('multivibrator.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=48owMmP_cd4')
  doc.close()

@bot.message_handler(commands=['comparator'])
def send_answer(message):
  doc=open('comparator.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=WK0MBcwAfUQ')
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=k9zQjEaKtfk')
  doc.close()

@bot.message_handler(commands=['schmitttrigger'])
def send_answer(message):
  doc=open('schmitt_trigger.pdf','rb')
  bot.send_document(message.chat.id,doc)
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=Sn0kSKEwrHY')
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=5-ohKRWeod4')
  doc.close()

@bot.message_handler(commands=['zerocrossing'])
def send_answer(message):
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=emxIw6P05lE')

@bot.message_handler(commands=['filters'])
def send_answer(message):
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=pe-rcape2SI')

@bot.message_handler(commands=['highpassfilter'])
def send_answer(message):
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=iS7wy3vL_M8')
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=YBThdTXlZvI')

@bot.message_handler(commands=['passbandfilter'])
def send_answer(message):
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=EA8JbFDWb3E')

@bot.message_handler(commands=['passbandfilter'])
def send_answer(message):
  bot.send_message(message.chat.id,'https://www.youtube.com/watch?v=EA8JbFDWb3E')



bot.polling()
